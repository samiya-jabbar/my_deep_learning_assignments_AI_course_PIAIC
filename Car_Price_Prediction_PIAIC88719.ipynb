# %% [markdown]
# <a href="https://colab.research.google.com/github/samiya-jabbar/my_deep_learning_assignments_AI_course_PIAIC/blob/main/Car_Price_Prediction_PIAIC88719.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
car_data = pd.read_csv('/content/drive/MyDrive/CarPrice_Assignment.csv')

# %%
car_data.head()
# Out:
#    symboling                   CarName fueltype  ... citympg highwaympg    price
# 0          3        alfa-romero giulia      gas  ...      21         27  13495.0
# 1          3       alfa-romero stelvio      gas  ...      21         27  16500.0
# 2          1  alfa-romero Quadrifoglio      gas  ...      19         26  16500.0
# 3          2                audi 100ls      gas  ...      24         30  13950.0
# 4          2                audi 100ls      gas  ...      18         22  17450.0
#
# [5 rows x 25 columns]

# %%
car_data['CarName'].unique()

# %%
np.where(car_data.applymap(lambda x: x ==''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
car_data.isnull().any()
# Out:
# car_ID              False
# symboling           False
# CarName             False
# fueltype            False
# aspiration          False
# doornumber          False
# carbody             False
# drivewheel          False
# enginelocation      False
# wheelbase           False
# carlength           False
# carwidth            False
# carheight           False
# curbweight          False
# enginetype          False
# cylindernumber      False
# enginesize          False
# fuelsystem          False
# boreratio           False
# stroke              False
# compressionratio    False
# horsepower          False
# peakrpm             False
# citympg             False
# highwaympg          False
# price               False
# dtype: bool

# %%
car_data.iloc[3,2] = 'audi 100ls'

# %%
car_data.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
car_data.drop(columns=['car_ID'], inplace = True)

# %%
car_data.columns

# %%
final_car = pd.get_dummies(car_data, columns=['CarName','symboling','fueltype',	'aspiration',	'doornumber',	'carbody',	'drivewheel',	'enginelocation',	'enginetype',	'cylindernumber',	'fuelsystem'], drop_first = True)

# %%
final_car.head()
# Out:
#    wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0       88.6      168.8  ...                0                0
# 1       88.6      168.8  ...                0                0
# 2       94.5      171.2  ...                0                0
# 3       99.8      176.6  ...                0                0
# 4       99.4      176.6  ...                0                0
#
# [5 rows x 193 columns]

# %%
final_car.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  205.000000  205.000000  ...       205.000000       205.000000
# mean    98.756585  174.049268  ...         0.043902         0.004878
# std      6.021776   12.337289  ...         0.205380         0.069843
# min     86.600000  141.100000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     97.000000  173.200000  ...         0.000000         0.000000
# 75%    102.400000  183.100000  ...         0.000000         0.000000
# max    120.900000  208.100000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
np.random.seed(11111)
msk = np.random.rand(len(final_car)) < 0.72
train_total = final_car[msk]
test_total = final_car[~msk]

# %%
print(len(train_total))
print(len(test_total))
# Out:
# 141
# 64

# %%
train_total.head(10)
# Out:
#     wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1        88.6      168.8  ...                0                0
# 2        94.5      171.2  ...                0                0
# 3        99.8      176.6  ...                0                0
# 4        99.4      176.6  ...                0                0
# 5        99.8      177.3  ...                0                0
# 6       105.8      192.7  ...                0                0
# 7       105.8      192.7  ...                0                0
# 8       105.8      192.7  ...                0                0
# 9        99.5      178.2  ...                0                0
# 11      101.2      176.8  ...                0                0
#
# [10 rows x 193 columns]

# %%
train_total.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  141.000000  141.000000  ...       141.000000       141.000000
# mean    98.692199  173.658156  ...         0.035461         0.007092
# std      6.005665   12.320089  ...         0.185601         0.084215
# min     86.600000  144.600000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     96.500000  172.400000  ...         0.000000         0.000000
# 75%    102.400000  180.300000  ...         0.000000         0.000000
# max    115.600000  202.600000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
print(train_total.dtypes)
# Out:
# wheelbase          float64
# carlength          float64
# carwidth           float64
# carheight          float64
# curbweight           int64
#                     ...
# fuelsystem_idi       uint8
# fuelsystem_mfi       uint8
# fuelsystem_mpfi      uint8
# fuelsystem_spdi      uint8
# fuelsystem_spfi      uint8
# Length: 193, dtype: object

# %%
train_label = train_total.loc[:,'price']
test_label = test_total.loc[:,'price']

# %%
train_label
# Out:
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 141, dtype: float64

# %%
test_data= test_total.drop(columns = ['price'])
train_data= train_total.drop(columns = ['price'])

# %%
train_data.shape
# Out:
# (141, 192)

# %%
train_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1         88.6      168.8  ...                0                0
# 2         94.5      171.2  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# 5         99.8      177.3  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      109.1      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      109.1      188.8  ...                0                0
# 203      109.1      188.8  ...                0                0
# 204      109.1      188.8  ...                0                0
#
# [141 rows x 192 columns]

# %%
{train_data.columns.get_loc(c): c for idx, c in enumerate(train_data.columns)}
# Out:
# {0: 'wheelbase',
#  1: 'carlength',
#  2: 'carwidth',
#  3: 'carheight',
#  4: 'curbweight',
#  5: 'enginesize',
#  6: 'boreratio',
#  7: 'stroke',
#  8: 'compressionratio',
#  9: 'horsepower',
#  10: 'peakrpm',
#  11: 'citympg',
#  12: 'highwaympg',
#  13: 'CarName_alfa-romero Quadrifoglio',
#  14: 'CarName_alfa-romero giulia',
#  15: 'CarName_alfa-romero stelvio',
#  16: 'CarName_audi 100ls',
#  17: 'CarName_audi 4000',
#  18: 'CarName_audi 5000',
#  19: 'CarName_audi 5000s (diesel)',
#  20: 'CarName_audi fox',
#  21: 'CarName_bmw 320i',
#  22: 'CarName_bmw x1',
#  23: 'CarName_bmw x3',
#  24: 'CarName_bmw x4',
#  25: 'CarName_bmw x5',
#  26: 'CarName_bmw z4',
#  27: 'CarName_buick century',
#  28: 'CarName_buick century luxus (sw)',
#  29: 'CarName_buick century special',
#  30: 'CarName_buick electra 225 custom',
#  31: 'CarName_buick opel isuzu deluxe',
#  32: 'CarName_buick regal sport coupe (turbo)',
#  33: 'CarName_buick skyhawk',
#  34: 'CarName_buick skylark',
#  35: 'CarName_chevrolet impala',
#  36: 'CarName_chevrolet monte carlo',
#  37: 'CarName_chevrolet vega 2300',
#  38: 'CarName_dodge challenger se',
#  39: 'CarName_dodge colt (sw)',
#  40: 'CarName_dodge colt hardtop',
#  41: 'CarName_dodge coronet custom',
#  42: 'CarName_dodge coronet custom (sw)',
#  43: 'CarName_dodge d200',
#  44: 'CarName_dodge dart custom',
#  45: 'CarName_dodge monaco (sw)',
#  46: 'CarName_dodge rampage',
#  47: 'CarName_honda accord',
#  48: 'CarName_honda accord cvcc',
#  49: 'CarName_honda accord lx',
#  50: 'CarName_honda civic',
#  51: 'CarName_honda civic (auto)',
#  52: 'CarName_honda civic 1300',
#  53: 'CarName_honda civic 1500 gl',
#  54: 'CarName_honda civic cvcc',
#  55: 'CarName_honda prelude',
#  56: 'CarName_isuzu D-Max ',
#  57: 'CarName_isuzu D-Max V-Cross',
#  58: 'CarName_isuzu MU-X',
#  59: 'CarName_jaguar xf',
#  60: 'CarName_jaguar xj',
#  61: 'CarName_jaguar xk',
#  62: 'CarName_maxda glc deluxe',
#  63: 'CarName_maxda rx3',
#  64: 'CarName_mazda 626',
#  65: 'CarName_mazda glc',
#  66: 'CarName_mazda glc 4',
#  67: 'CarName_mazda glc custom',
#  68: 'CarName_mazda glc custom l',
#  69: 'CarName_mazda glc deluxe',
#  70: 'CarName_mazda rx-4',
#  71: 'CarName_mazda rx-7 gs',
#  72: 'CarName_mazda rx2 coupe',
#  73: 'CarName_mercury cougar',
#  74: 'CarName_mitsubishi g4',
#  75: 'CarName_mitsubishi lancer',
#  76: 'CarName_mitsubishi mirage',
#  77: 'CarName_mitsubishi mirage g4',
#  78: 'CarName_mitsubishi montero',
#  79: 'CarName_mitsubishi outlander',
#  80: 'CarName_mitsubishi pajero',
#  81: 'CarName_nissan clipper',
#  82: 'CarName_nissan dayz',
#  83: 'CarName_nissan fuga',
#  84: 'CarName_nissan gt-r',
#  85: 'CarName_nissan juke',
#  86: 'CarName_nissan kicks',
#  87: 'CarName_nissan latio',
#  88: 'CarName_nissan leaf',
#  89: 'CarName_nissan note',
#  90: 'CarName_nissan nv200',
#  91: 'CarName_nissan otti',
#  92: 'CarName_nissan rogue',
#  93: 'CarName_nissan teana',
#  94: 'CarName_nissan titan',
#  95: 'CarName_peugeot 304',
#  96: 'CarName_peugeot 504',
#  97: 'CarName_peugeot 504 (sw)',
#  98: 'CarName_peugeot 505s turbo diesel',
#  99: 'CarName_peugeot 604sl',
#  100: 'CarName_plymouth cricket',
#  101: 'CarName_plymouth duster',
#  102: 'CarName_plymouth fury gran sedan',
#  103: 'CarName_plymouth fury iii',
#  104: 'CarName_plymouth satellite custom (sw)',
#  105: 'CarName_plymouth valiant',
#  106: 'CarName_porcshce panamera',
#  107: 'CarName_porsche boxter',
#  108: 'CarName_porsche cayenne',
#  109: 'CarName_porsche macan',
#  110: 'CarName_renault 12tl',
#  111: 'CarName_renault 5 gtl',
#  112: 'CarName_saab 99e',
#  113: 'CarName_saab 99gle',
#  114: 'CarName_saab 99le',
#  115: 'CarName_subaru',
#  116: 'CarName_subaru baja',
#  117: 'CarName_subaru brz',
#  118: 'CarName_subaru dl',
#  119: 'CarName_subaru r1',
#  120: 'CarName_subaru r2',
#  121: 'CarName_subaru trezia',
#  122: 'CarName_subaru tribeca',
#  123: 'CarName_toyota carina',
#  124: 'CarName_toyota celica gt',
#  125: 'CarName_toyota celica gt liftback',
#  126: 'CarName_toyota corolla',
#  127: 'CarName_toyota corolla 1200',
#  128: 'CarName_toyota corolla 1600 (sw)',
#  129: 'CarName_toyota corolla liftback',
#  130: 'CarName_toyota corolla tercel',
#  131: 'CarName_toyota corona',
#  132: 'CarName_toyota corona hardtop',
#  133: 'CarName_toyota corona liftback',
#  134: 'CarName_toyota corona mark ii',
#  135: 'CarName_toyota cressida',
#  136: 'CarName_toyota mark ii',
#  137: 'CarName_toyota starlet',
#  138: 'CarName_toyota tercel',
#  139: 'CarName_toyouta tercel',
#  140: 'CarName_vokswagen rabbit',
#  141: 'CarName_volkswagen 1131 deluxe sedan',
#  142: 'CarName_volkswagen 411 (sw)',
#  143: 'CarName_volkswagen dasher',
#  144: 'CarName_volkswagen model 111',
#  145: 'CarName_volkswagen rabbit',
#  146: 'CarName_volkswagen rabbit custom',
#  147: 'CarName_volkswagen super beetle',
#  148: 'CarName_volkswagen type 3',
#  149: 'CarName_volvo 144ea',
#  150: 'CarName_volvo 145e (sw)',
#  151: 'CarName_volvo 244dl',
#  152: 'CarName_volvo 245',
#  153: 'CarName_volvo 246',
#  154: 'CarName_volvo 264gl',
#  155: 'CarName_volvo diesel',
#  156: 'CarName_vw dasher',
#  157: 'CarName_vw rabbit',
#  158: 'symboling_-1',
#  159: 'symboling_0',
#  160: 'symboling_1',
#  161: 'symboling_2',
#  162: 'symboling_3',
#  163: 'fueltype_gas',
#  164: 'aspiration_turbo',
#  165: 'doornumber_two',
#  166: 'carbody_hardtop',
#  167: 'carbody_hatchback',
#  168: 'carbody_sedan',
#  169: 'carbody_wagon',
#  170: 'drivewheel_fwd',
#  171: 'drivewheel_rwd',
#  172: 'enginelocation_rear',
#  173: 'enginetype_dohcv',
#  174: 'enginetype_l',
#  175: 'enginetype_ohc',
#  176: 'enginetype_ohcf',
#  177: 'enginetype_ohcv',
#  178: 'enginetype_rotor',
#  179: 'cylindernumber_five',
#  180: 'cylindernumber_four',
#  181: 'cylindernumber_six',
#  182: 'cylindernumber_three',
#  183: 'cylindernumber_twelve',
#  184: 'cylindernumber_two',
#  185: 'fuelsystem_2bbl',
#  186: 'fuelsystem_4bbl',
#  187: 'fuelsystem_idi',
#  188: 'fuelsystem_mfi',
#  189: 'fuelsystem_mpfi',
#  190: 'fuelsystem_spdi',
#  191: 'fuelsystem_spfi'}

# %%
mean = train_data.iloc[:,0:13].mean(axis=0) # taking the mean of 
train_data.iloc[:,0:13] -= mean
std = train_data.iloc[:,0:13].std(axis=0)
train_data.iloc[:,0:13] /= std
test_data.iloc[:,0:13] -= mean
test_data.iloc[:,0:13] /= std

# %%
print (mean)
print(std)
# Out:
# wheelbase             98.692199
# carlength            173.658156
# carwidth              65.875887
# carheight             53.648227
# curbweight          2546.787234
# enginesize           125.666667
# boreratio              3.324184
# stroke                 3.256809
# compressionratio      10.070355
# horsepower           103.702128
# peakrpm             5143.971631
# citympg               25.113475
# highwaympg            30.581560
# dtype: float64
# wheelbase             6.005665
# carlength            12.320089
# carwidth              2.188604
# carheight             2.508204
# curbweight          529.769152
# enginesize           41.733451
# boreratio             0.266123
# stroke                0.296387
# compressionratio      3.868579
# horsepower           38.424275
# peakrpm             474.472458
# citympg               6.509435
# highwaympg            6.734937
# dtype: float64

# %%
mean_label = train_label.mean()
train_label -= mean_label
std_label = train_label.std()
train_label /= std_label
test_label -= mean_label
test_label /= std_label

# %%
print(mean_label)
print(std_label)
# Out:
# 13379.132390070921
# 8189.4945680106175

# %%
test_label
# Out:
# 0      0.014148
# 10     0.372534
# 14     1.365880
# 15     2.122337
# 18    -1.004718
#          ...
# 192    0.056886
# 193   -0.132991
# 194   -0.053621
# 196    0.318196
# 198    0.615529
# Name: price, Length: 64, dtype: float64

# %%
train_data.shape
# Out:
# (141, 192)

# %%
test = np.array(test_data.iloc[:]).astype('float32')

# %%
train = np.array(train_data.iloc[:]).astype('float32')

# %%
test_l= np.array(test_label.astype('float32'))

# %%
train_l= np.array(train_label.astype('float32'))

# %%
train.shape[1]
# Out:
# 192

# %%
train.dtype
# Out:
# dtype('float32')

# %%
from keras import models
from keras import layers
def build_model(act):
  model = models.Sequential()
  model.add(layers.Dense(128, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dense(64, activation= act))
  model.add(layers.Dense(32, activation= act))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               24704
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Regularized model
from keras import regularizers
def build_model_regular(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001),input_shape=(train.shape[1],)))
  model.add(layers.Dense(8, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(6, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
# dropout model
from keras import regularizers
def build_model_drop(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(8, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(6, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_relu = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_relu.append(val_mae)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %%
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_tanh = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('tanh')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_tanh.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0c4f682050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0c44631b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0c46124d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0c499ec950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with regularization
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_regular = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_regular('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_regular.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0c472714d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0c42bb3a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0c41919d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0c4f54e290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with dropout
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_drop = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_drop('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=1)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
  all_scores_drop.append(val_mae)
# Out:
# processing fold # 0
# Epoch 1/100
# 106/106 [==============================] - 1s 932us/step - loss: 1.0294 - mae: 0.6473
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6695 - mae: 0.5078
# Epoch 3/100
# 106/106 [==============================] - 0s 974us/step - loss: 0.5592 - mae: 0.4972
# Epoch 4/100
# 106/106 [==============================] - 0s 885us/step - loss: 0.4666 - mae: 0.4266
# Epoch 5/100
# 106/106 [==============================] - 0s 939us/step - loss: 0.2962 - mae: 0.3924
# Epoch 6/100
# 106/106 [==============================] - 0s 905us/step - loss: 0.2538 - mae: 0.3476
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5272 - mae: 0.4629
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2631 - mae: 0.3797
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2679 - mae: 0.3681
# Epoch 10/100
# 106/106 [==============================] - 0s 948us/step - loss: 0.4021 - mae: 0.3921
# Epoch 11/100
# 106/106 [==============================] - 0s 905us/step - loss: 0.4234 - mae: 0.3883
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1656 - mae: 0.2887
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1609 - mae: 0.2592
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5559 - mae: 0.4622
# Epoch 15/100
# 106/106 [==============================] - 0s 930us/step - loss: 0.1960 - mae: 0.3150
# Epoch 16/100
# 106/106 [==============================] - 0s 906us/step - loss: 0.2479 - mae: 0.3548
# Epoch 17/100
# 106/106 [==============================] - 0s 897us/step - loss: 0.1494 - mae: 0.2831
# Epoch 18/100
# 106/106 [==============================] - 0s 932us/step - loss: 0.4691 - mae: 0.4189
# Epoch 19/100
# 106/106 [==============================] - 0s 934us/step - loss: 0.2581 - mae: 0.3333
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2755 - mae: 0.3544
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3922 - mae: 0.4164
# Epoch 22/100
# 106/106 [==============================] - 0s 934us/step - loss: 0.4981 - mae: 0.4559
# Epoch 23/100
# 106/106 [==============================] - 0s 922us/step - loss: 0.6947 - mae: 0.4915
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3072 - mae: 0.4106
# Epoch 25/100
# 106/106 [==============================] - 0s 992us/step - loss: 0.3139 - mae: 0.3321
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1366 - mae: 0.2644
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3173 - mae: 0.3329
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2305 - mae: 0.3061
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2508 - mae: 0.3229
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1954 - mae: 0.2844
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3452 - mae: 0.3841
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1845 - mae: 0.2971
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2782 - mae: 0.2541
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2517 - mae: 0.3421
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2413 - mae: 0.2966
# Epoch 36/100
# 106/106 [==============================] - 0s 920us/step - loss: 0.1316 - mae: 0.2514
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2513 - mae: 0.3128
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3620 - mae: 0.3359
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2363 - mae: 0.2891
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2232 - mae: 0.2962
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2976 - mae: 0.3158
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3544 - mae: 0.3489
# Epoch 43/100
# 106/106 [==============================] - 0s 933us/step - loss: 0.3134 - mae: 0.3228
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2039 - mae: 0.2691
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2136 - mae: 0.3292
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4461 - mae: 0.3676
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1959 - mae: 0.2690
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3389 - mae: 0.3415
# Epoch 49/100
# 106/106 [==============================] - 0s 950us/step - loss: 0.1998 - mae: 0.2813
# Epoch 50/100
# 106/106 [==============================] - 0s 925us/step - loss: 0.4714 - mae: 0.3414
# Epoch 51/100
# 106/106 [==============================] - 0s 932us/step - loss: 0.2186 - mae: 0.3009
# Epoch 52/100
# 106/106 [==============================] - 0s 934us/step - loss: 0.1564 - mae: 0.2707
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7937 - mae: 0.3798
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3223 - mae: 0.3480
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2215 - mae: 0.2979
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2163 - mae: 0.3030
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1913 - mae: 0.2869
# Epoch 58/100
# 106/106 [==============================] - 0s 922us/step - loss: 0.3139 - mae: 0.3165
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2618 - mae: 0.3286
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3363 - mae: 0.3207
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3123 - mae: 0.3200
# Epoch 62/100
# 106/106 [==============================] - 0s 991us/step - loss: 0.2179 - mae: 0.2597
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7539 - mae: 0.5488
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1880 - mae: 0.2587
# Epoch 65/100
# 106/106 [==============================] - 0s 976us/step - loss: 0.2708 - mae: 0.2774
# Epoch 66/100
# 106/106 [==============================] - 0s 890us/step - loss: 0.3526 - mae: 0.3167
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3441 - mae: 0.3285
# Epoch 68/100
# 106/106 [==============================] - 0s 954us/step - loss: 0.3822 - mae: 0.3602
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2798 - mae: 0.3205
# Epoch 70/100
# 106/106 [==============================] - 0s 1000us/step - loss: 0.1657 - mae: 0.2609
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1582 - mae: 0.2124
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1800 - mae: 0.2831
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1708 - mae: 0.2908
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2596 - mae: 0.2893
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4506 - mae: 0.3435
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1545 - mae: 0.2345
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1489 - mae: 0.2535
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3036 - mae: 0.3282
# Epoch 79/100
# 106/106 [==============================] - 0s 990us/step - loss: 0.7949 - mae: 0.5240
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3405 - mae: 0.3387
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2509 - mae: 0.2839
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4530 - mae: 0.4124
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4392 - mae: 0.3740
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1605 - mae: 0.2558
# Epoch 85/100
# 106/106 [==============================] - 0s 988us/step - loss: 0.1581 - mae: 0.2591
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2130 - mae: 0.2765
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1735 - mae: 0.2599
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2043 - mae: 0.2924
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2912 - mae: 0.3004
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1213 - mae: 0.2281
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1364 - mae: 0.2495
# Epoch 92/100
# 106/106 [==============================] - 0s 931us/step - loss: 0.1686 - mae: 0.2907
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1587 - mae: 0.2536
# Epoch 94/100
# 106/106 [==============================] - 0s 936us/step - loss: 0.3984 - mae: 0.2878
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1520 - mae: 0.2570
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4643 - mae: 0.3949
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1544 - mae: 0.2206
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2791 - mae: 0.3248
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3068 - mae: 0.2728
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3344 - mae: 0.3156
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0c42baab90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3813 - mae: 0.4298
# processing fold # 1
# Epoch 1/100
# 106/106 [==============================] - 1s 952us/step - loss: 0.5809 - mae: 0.5670
# Epoch 2/100
# 106/106 [==============================] - 0s 907us/step - loss: 0.4740 - mae: 0.4681
# Epoch 3/100
# 106/106 [==============================] - 0s 923us/step - loss: 0.7463 - mae: 0.6359
# Epoch 4/100
# 106/106 [==============================] - 0s 976us/step - loss: 0.8638 - mae: 0.5679
# Epoch 5/100
# 106/106 [==============================] - 0s 911us/step - loss: 0.5166 - mae: 0.4878
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3298 - mae: 0.4385
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3250 - mae: 0.4009
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2877 - mae: 0.3773
# Epoch 9/100
# 106/106 [==============================] - 0s 924us/step - loss: 0.3978 - mae: 0.4476
# Epoch 10/100
# 106/106 [==============================] - 0s 948us/step - loss: 0.4622 - mae: 0.4417
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4022 - mae: 0.3814
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7237 - mae: 0.5551
# Epoch 13/100
# 106/106 [==============================] - 0s 932us/step - loss: 0.4684 - mae: 0.4535
# Epoch 14/100
# 106/106 [==============================] - 0s 897us/step - loss: 0.4735 - mae: 0.4681
# Epoch 15/100
# 106/106 [==============================] - 0s 928us/step - loss: 0.5926 - mae: 0.4696
# Epoch 16/100
# 106/106 [==============================] - 0s 958us/step - loss: 0.3511 - mae: 0.3724
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3252 - mae: 0.3751
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4565 - mae: 0.4465
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3673 - mae: 0.3903
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1793 - mae: 0.3084
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2596 - mae: 0.3552
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4128 - mae: 0.4067
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1641 - mae: 0.2976
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2047 - mae: 0.3158
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2533 - mae: 0.2792
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3300 - mae: 0.3825
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2230 - mae: 0.3023
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3379 - mae: 0.3793
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2960 - mae: 0.3257
# Epoch 30/100
# 106/106 [==============================] - 0s 982us/step - loss: 0.3325 - mae: 0.3935
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3510 - mae: 0.3778
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3725 - mae: 0.4040
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1713 - mae: 0.3045
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2358 - mae: 0.3262
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2249 - mae: 0.3352
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1348 - mae: 0.2609
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1517 - mae: 0.2728
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1936 - mae: 0.2805
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1207 - mae: 0.2459
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1693 - mae: 0.3110
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2223 - mae: 0.3128
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1984 - mae: 0.3005
# Epoch 43/100
# 106/106 [==============================] - 0s 937us/step - loss: 0.5028 - mae: 0.4259
# Epoch 44/100
# 106/106 [==============================] - 0s 928us/step - loss: 0.1448 - mae: 0.2352
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1716 - mae: 0.2993
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4073 - mae: 0.3926
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4278 - mae: 0.3583
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1186 - mae: 0.2607
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2727 - mae: 0.3533
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2296 - mae: 0.2894
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2355 - mae: 0.2879
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1120 - mae: 0.2426
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4191 - mae: 0.3541
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1902 - mae: 0.3037
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1307 - mae: 0.2626
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4113 - mae: 0.3462
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1405 - mae: 0.2599
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2634 - mae: 0.3042
# Epoch 59/100
# 106/106 [==============================] - 0s 959us/step - loss: 0.1406 - mae: 0.2526
# Epoch 60/100
# 106/106 [==============================] - 0s 954us/step - loss: 0.4095 - mae: 0.3458
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2064 - mae: 0.2797
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1628 - mae: 0.2400
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1088 - mae: 0.2376
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0856 - mae: 0.2270
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1498 - mae: 0.2640
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1858 - mae: 0.3026
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1870 - mae: 0.2664
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1269 - mae: 0.2959
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2946 - mae: 0.3110
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2364 - mae: 0.3095
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1400 - mae: 0.2665
# Epoch 72/100
# 106/106 [==============================] - 0s 947us/step - loss: 0.2196 - mae: 0.2868
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3307 - mae: 0.3729
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0955 - mae: 0.2551
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1673 - mae: 0.2578
# Epoch 76/100
# 106/106 [==============================] - 0s 975us/step - loss: 0.2079 - mae: 0.3014
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0871 - mae: 0.2386
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1273 - mae: 0.2363
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1292 - mae: 0.2538
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0997 - mae: 0.2281
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3970 - mae: 0.3467
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1552 - mae: 0.2630
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1347 - mae: 0.2687
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1820 - mae: 0.2976
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1376 - mae: 0.2593
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1823 - mae: 0.3092
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2469 - mae: 0.3206
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2070 - mae: 0.2992
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1085 - mae: 0.2532
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2157 - mae: 0.2863
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1339 - mae: 0.2554
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1233 - mae: 0.2249
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1579 - mae: 0.2325
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2397 - mae: 0.2748
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2690 - mae: 0.2859
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2875 - mae: 0.3193
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1246 - mae: 0.2451
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1508 - mae: 0.3007
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1495 - mae: 0.2518
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1332 - mae: 0.2314
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0c46124e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5297 - mae: 0.4687
# processing fold # 2
# Epoch 1/100
# 106/106 [==============================] - 1s 953us/step - loss: 0.5746 - mae: 0.5360
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0341 - mae: 0.6308
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5112 - mae: 0.4615
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4336 - mae: 0.4487
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2768 - mae: 0.3721
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2600 - mae: 0.3828
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5735 - mae: 0.5251
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2520 - mae: 0.3526
# Epoch 9/100
# 106/106 [==============================] - 0s 933us/step - loss: 0.3151 - mae: 0.3901
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4738 - mae: 0.4713
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5247 - mae: 0.4677
# Epoch 12/100
# 106/106 [==============================] - 0s 956us/step - loss: 0.1654 - mae: 0.2827
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2013 - mae: 0.3298
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2521 - mae: 0.3431
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4009 - mae: 0.3925
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3105 - mae: 0.3926
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4276 - mae: 0.3926
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2005 - mae: 0.3235
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3685 - mae: 0.3884
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2625 - mae: 0.3913
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6449 - mae: 0.4422
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3651 - mae: 0.4016
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2370 - mae: 0.3011
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2864 - mae: 0.3672
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5275 - mae: 0.4353
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3468 - mae: 0.3203
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2173 - mae: 0.3192
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2124 - mae: 0.3205
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2138 - mae: 0.3357
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4207 - mae: 0.3622
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4783 - mae: 0.3951
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1466 - mae: 0.2746
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1901 - mae: 0.2950
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1935 - mae: 0.3015
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2089 - mae: 0.3215
# Epoch 36/100
# 106/106 [==============================] - 0s 979us/step - loss: 0.7278 - mae: 0.5368
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1181 - mae: 0.2410
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4309 - mae: 0.3559
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3516 - mae: 0.3900
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4181 - mae: 0.3685
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1731 - mae: 0.3182
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2454 - mae: 0.3147
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1915 - mae: 0.2780
# Epoch 44/100
# 106/106 [==============================] - 0s 949us/step - loss: 0.1651 - mae: 0.2571
# Epoch 45/100
# 106/106 [==============================] - 0s 927us/step - loss: 0.2141 - mae: 0.3059
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2443 - mae: 0.3013
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2531 - mae: 0.3038
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2127 - mae: 0.2813
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2355 - mae: 0.2743
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3197 - mae: 0.3386
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3044 - mae: 0.3340
# Epoch 52/100
# 106/106 [==============================] - 0s 931us/step - loss: 0.2549 - mae: 0.2728
# Epoch 53/100
# 106/106 [==============================] - 0s 947us/step - loss: 0.5086 - mae: 0.3947
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2239 - mae: 0.2944
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4779 - mae: 0.3966
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1972 - mae: 0.2840
# Epoch 57/100
# 106/106 [==============================] - 0s 975us/step - loss: 0.1385 - mae: 0.2309
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1556 - mae: 0.2549
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2209 - mae: 0.3104
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1660 - mae: 0.2503
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1774 - mae: 0.2666
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2495 - mae: 0.3123
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2152 - mae: 0.3092
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2689 - mae: 0.3118
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1354 - mae: 0.2124
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1906 - mae: 0.2525
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1737 - mae: 0.2775
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7416 - mae: 0.4380
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3139 - mae: 0.2730
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2830 - mae: 0.2713
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1538 - mae: 0.2477
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1974 - mae: 0.2775
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2552 - mae: 0.3068
# Epoch 74/100
# 106/106 [==============================] - 0s 935us/step - loss: 0.1579 - mae: 0.2204
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3147 - mae: 0.3517
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2788 - mae: 0.2730
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1758 - mae: 0.2638
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2414 - mae: 0.2905
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1143 - mae: 0.2205
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2475 - mae: 0.3118
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2845 - mae: 0.3059
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5817 - mae: 0.4425
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3315 - mae: 0.3122
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3025 - mae: 0.2962
# Epoch 85/100
# 106/106 [==============================] - 0s 979us/step - loss: 0.2707 - mae: 0.3200
# Epoch 86/100
# 106/106 [==============================] - 0s 947us/step - loss: 0.1463 - mae: 0.2531
# Epoch 87/100
# 106/106 [==============================] - 0s 951us/step - loss: 0.1966 - mae: 0.2945
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2529 - mae: 0.2929
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1286 - mae: 0.1950
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2015 - mae: 0.2751
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2466 - mae: 0.3087
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4393 - mae: 0.3476
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2694 - mae: 0.2692
# Epoch 94/100
# 106/106 [==============================] - 0s 948us/step - loss: 0.1578 - mae: 0.2403
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1688 - mae: 0.2890
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2234 - mae: 0.2731
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3458 - mae: 0.3609
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1651 - mae: 0.2762
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1809 - mae: 0.2828
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1863 - mae: 0.2672
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0c5e958560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3931 - mae: 0.4155
# processing fold # 3
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.8208 - mae: 0.6506
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0028 - mae: 0.7127
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6369 - mae: 0.5424
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9001 - mae: 0.6349
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8347 - mae: 0.6644
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7549 - mae: 0.6077
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8369 - mae: 0.5658
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5402 - mae: 0.5013
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7408 - mae: 0.5750
# Epoch 10/100
# 106/106 [==============================] - 0s 955us/step - loss: 0.4292 - mae: 0.4729
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5378 - mae: 0.5477
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5284 - mae: 0.5080
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4806 - mae: 0.4690
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7358 - mae: 0.5947
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5381 - mae: 0.4713
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8584 - mae: 0.5529
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5557 - mae: 0.5441
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6117 - mae: 0.5568
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3126 - mae: 0.4045
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3743 - mae: 0.4232
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5656 - mae: 0.5301
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4221 - mae: 0.4425
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6425 - mae: 0.5033
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5272 - mae: 0.4836
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5492 - mae: 0.5117
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2811 - mae: 0.3890
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4763 - mae: 0.4137
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3120 - mae: 0.3787
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7816 - mae: 0.5389
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5623 - mae: 0.4935
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5520 - mae: 0.4701
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2861 - mae: 0.3878
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4121 - mae: 0.4282
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2131 - mae: 0.3615
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5020 - mae: 0.4473
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2987 - mae: 0.3821
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5053 - mae: 0.4470
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5881 - mae: 0.4896
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3066 - mae: 0.3806
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2374 - mae: 0.3263
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7540 - mae: 0.5518
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6243 - mae: 0.4826
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2936 - mae: 0.3574
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4070 - mae: 0.4111
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4274 - mae: 0.3653
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4529 - mae: 0.3979
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3965 - mae: 0.4076
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4511 - mae: 0.4609
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2045 - mae: 0.3291
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2154 - mae: 0.3369
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1766 - mae: 0.2941
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5824 - mae: 0.4535
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3910 - mae: 0.3872
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3067 - mae: 0.3588
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3837 - mae: 0.4349
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2589 - mae: 0.3455
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4574 - mae: 0.3998
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1918 - mae: 0.3071
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2233 - mae: 0.3432
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2726 - mae: 0.3517
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2016 - mae: 0.3273
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3537 - mae: 0.3824
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3810 - mae: 0.3791
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2297 - mae: 0.3244
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2887 - mae: 0.3240
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4063 - mae: 0.4017
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3020 - mae: 0.3576
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3097 - mae: 0.3991
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1734 - mae: 0.2827
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2044 - mae: 0.2837
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3963 - mae: 0.3461
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6498 - mae: 0.4574
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3704 - mae: 0.3467
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9011 - mae: 0.5361
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1035 - mae: 0.2162
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2324 - mae: 0.3256
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2417 - mae: 0.3249
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4471 - mae: 0.4239
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4774 - mae: 0.3827
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3532 - mae: 0.3893
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3470 - mae: 0.3553
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2456 - mae: 0.3494
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4017 - mae: 0.4179
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2131 - mae: 0.3457
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5363 - mae: 0.3937
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3303 - mae: 0.3987
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3311 - mae: 0.3494
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2705 - mae: 0.3119
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2663 - mae: 0.3515
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2948 - mae: 0.3580
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5243 - mae: 0.4181
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4424 - mae: 0.3715
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2658 - mae: 0.3139
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3382 - mae: 0.4134
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2209 - mae: 0.3440
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3320 - mae: 0.3253
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5469 - mae: 0.4408
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2371 - mae: 0.2940
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1516 - mae: 0.2968
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3945 - mae: 0.3761
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0c406cdc20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1198 - mae: 0.2936

# %%
print(all_scores_relu)
print(all_scores_tanh)
print(all_scores_regular)
print(all_scores_drop)
# Out:
# [0.3207786977291107, 0.3310289680957794, 0.3566279411315918, 0.2850554585456848]
# [0.28776729106903076, 0.24633418023586273, 0.4075266122817993, 0.3751673400402069]
# [0.384753555059433, 0.23357604444026947, 0.38113439083099365, 0.36826783418655396]
# [0.42982977628707886, 0.4687403440475464, 0.4154523015022278, 0.2936127483844757]

# %%
model_tanh = build_model('tanh')
model_tanh.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_tanh.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0c433d1200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0988 - mae: 0.2396

# %%
model_relu = build_model('relu')
model_relu.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_relu.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0c4729f8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0819 - mae: 0.2243

# %%
model_regular = build_model_regular('relu')
model_regular.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_regular.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0c42a873b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1659 - mae: 0.2719

# %%
model_drop = build_model_drop('relu')
model_drop.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_drop.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0c4729f170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1629 - mae: 0.3169

# %%
test_l
# Out:
# array([ 0.01414832,  0.3725343 ,  1.3658801 ,  2.122337  , -1.004718  ,
#        -0.7045773 , -0.5886972 , -0.97443527, -0.763189  , -0.52312535,
#        -0.05301089, -0.3704908 , -0.5449216 , -0.80397296, -0.5536523 ,
#        -0.26059392,  0.6062484 ,  1.4864004 ,  2.5404336 ,  3.367835  ,
#        -0.8779702 , -0.09159691,  0.18192424, -0.7802841 , -0.50065756,
#        -0.9622245 , -0.6813769 , -0.5409531 ,  0.01463675,  0.12453365,
#         0.46643507, -0.1806134 ,  0.2687428 ,  0.4299249 ,  0.45129374,
#        -0.07511237,  2.3382235 ,  2.200547  , -0.49870384,  0.20280465,
#         0.26019526, -0.68430746, -0.7224051 , -0.65524584, -0.98066276,
#        -0.7889537 , -0.7547636 , -0.6888255 , -0.6277716 , -0.4983375 ,
#        -0.6020069 , -0.4139611 , -0.22347318, -0.54107517,  0.28217462,
#        -0.68430746, -0.6574438 , -0.59638995, -0.01027321,  0.056886  ,
#        -0.1329914 , -0.05362143,  0.3181964 ,  0.6155285 ], dtype=float32)

# %%
def predict(model, m):
  print(f" the Actual value Price was : {test_l[m]* std_label + mean_label} " )
  return(f" the predicted Price was : {(model.predict(test[m:m+1].reshape(1,test.shape[1]))) * std_label + mean_label} ")

# %%
x_tanh = predict(model_tanh,2)
x_tanh
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[20766.707]] '

# %%
x_relu = predict(model_relu,2)
x_relu
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[20513.709]] '

# %%
x_regular = predict(model_regular,2)
x_regular
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[26495.453]] '

# %%
x_drop = predict(model_drop,2)
x_drop
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[19519.666]] '

# %%
def plot_fn(mod):
  y_true = test_l* std_label + mean_label
  y_pred = mod.predict(test) * std_label + mean_label
  return y_true , y_pred.flatten()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def plotting(mod, label):
  y_true, y_pred = plot_fn(mod)
  coef = np.polyfit(y_true,y_pred,1)
  poly1d_fn = np.poly1d(coef) 
  # poly1d_fn is now a function which takes in x and returns an estimate for y
  plt.figure()
  plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
  plt.title(label)
  plt.xlabel('Thousand Dollar True' )
  plt.ylabel('Thousand Dollar Predictions' )
  plt.xlim(0, 50000)
  plt.ylim(0, 50000)

# %%
plot_list = []
for i,j in enumerate([model_relu, model_tanh, model_regular, model_drop]):
  list_name = ['model_relu', 'model_tanh', 'model_regular', 'model_drop']
  plot_list.append(plotting(j,list_name[i]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0c433cd050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0c499ec5f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0c44631d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0c46124e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
